# %%
import matplotlib.pyplot as plt

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal gdp")
plt.ylabel("bln $")
# Out:
# Text(0, 0.5, 'bln $')

# %%
movies = ["Anny Holy", "Ben Gur", "Kasablanka", "Handy", "Westside story"]
num_oscars = [5,11,3,8,10]

# %%
for i,x in enumerate(movies):
    print(i,x)
# Out:
# 0 Anny Holy
# 1 Ben Gur
# 2 Kasablanka
# 3 Handy
# 4 Westside story

# %%
xs = [i+0.1 for i, _ in enumerate(movies)]

# %%
plt.bar(xs, num_oscars)
plt.ylabel("Prizes")
plt.xlabel("Movies")
plt.xticks([i+0.1 for i, _ in enumerate(movies)],movies)
# Out:
# ([<matplotlib.axis.XTick at 0x1e3cd5d7a10>,
#   <matplotlib.axis.XTick at 0x1e3cd5d6950>,
#   <matplotlib.axis.XTick at 0x1e3cd3a3190>,
#   <matplotlib.axis.XTick at 0x1e3cd60b510>,
#   <matplotlib.axis.XTick at 0x1e3cd60d650>],
#  [Text(0.1, 0, 'Anny Holy'),
#   Text(1.1, 0, 'Ben Gur'),
#   Text(2.1, 0, 'Kasablanka'),
#   Text(3.1, 0, 'Handy'),
#   Text(4.1, 0, 'Westside story')])

# %%
import collections as clc
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade//10*10
histogram = clc.Counter(decile(grade) for grade in grades)
plt.bar([x for x in histogram.keys()], histogram.values(), 8)
# Out:
# <BarContainer object of 6 artists>
